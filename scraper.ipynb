# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install html5lib
# Out:
# Requirement already satisfied: requests in c:\users\jyri\anaconda3\envs\ids\lib\site-packages (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jyri\anaconda3\envs\ids\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jyri\anaconda3\envs\ids\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jyri\anaconda3\envs\ids\lib\site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jyri\anaconda3\envs\ids\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: beautifulsoup4 in c:\users\jyri\anaconda3\envs\ids\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jyri\anaconda3\envs\ids\lib\site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: html5lib in c:\users\jyri\anaconda3\envs\ids\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\jyri\anaconda3\envs\ids\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\jyri\anaconda3\envs\ids\lib\site-packages (from html5lib) (0.5.1)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import html5lib

# %%
cookies = {
    'saved_searches': 'ae1b0536cef346eebdded88a3f6632b4',
    'OptanonConsent': 'isIABGlobal=false&datestamp=Sun+Nov+28+2021+14%3A16%3A13+GMT%2B0200+(Eastern+European+Standard+Time)&version=6.16.0&hosts=&landingPath=NotLandingPage&groups=C0003%3A0%2CC0001%3A1%2CC0004%3A0%2CC0002%3A0%2CSTACK42%3A0&geolocation=EE%3B79&AwaitingReconsent=false',
    'OptanonAlertBoxClosed': '2021-09-29T11:27:21.911Z',
    'eupubconsent-v2': 'CPNSwfVPNSwfVAcABBENB3CgAAAAAH_AAChQIJtf_X__b3_j-_59f_t0eY1P9_7_v-0zjhfdt-8N2f_X_L8X42M7vF36pq4KuR4Eu3LBIQdlHOHcTUmw6okVrzPsbk2Mr7NKJ7PEmnMbO2dYGH9_n93TuZKY7__8___z_v-v_v____f_r-3_3__5_X---_e_V399zLv9____39nN___9ggmASYal5AF2JY4Mm0aVQogRhWEh0AoAKKAYWiKwgZXBTsrgI9QQsAEJqAjAiBBiCjBgEAAgEASERASAHggEQBEAgABACpAQgAI2AQWAFgYBAAKAaFiBFAEIEhBkcFRymBARItFBPZWAJQd7GmEIZZYAUCj-iowEShBAsDISFg5jgCQEuAAA.YAAAD_gAAAAA',
    'gallery_view': '0',
    'kv_web': '22a46a03b5604519524e8f81a28da69d',
    'page_size': '50',
    'LVO': '3332078%7C2151270%7C3331457',
    'lang': 'en',
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:91.0) Gecko/20100101 Firefox/91.0',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    # 'Referer': 'https://www.kv.ee/?act=search.simple&last_deal_type=3&deal_type=3&dt_select=3&search_type=old',
    'DNT': '1',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-User': '?1',
    'Cache-Control': 'max-age=0',
    'TE': 'trailers',
}

# %%
def get_listing_urls(base_url, n_pages, cookies, headers, existing_links=[], verbose=False):
    # Converted using https://curlconverter.com/.

    links = []

    for i in range(1, n_pages + 1):
        response = requests.get(base_url + str(i), headers=headers, cookies=cookies)
        # print(response)
        if response.status_code != 200:
            print(f"Bad request, status code {response.status_code}.")
            continue

        soup = BeautifulSoup(response.text, 'html.parser')
        advertisement_links = soup.findAll('a', attrs={"class":"object-title-a text-truncate"})
        # print(advertisement_links)
        for content in advertisement_links:
            link = content["href"]
            # print(link)

            if not link in existing_links:
                links.append(link)
                if verbose:
                    print(f"Link added! {link}")
            else:
                if verbose:
                    print(f"Link already exists! {link}")

        print(f"Links so far: {len(links)}.")

    return links

# %% [markdown]
# ### Houses

# %%
# We do not want to parse already existing listings.
existing_links_houses = pd.read_csv("dataset_houses.csv").Link.values
base_url_houses = "https://www.kv.ee/?act=search.simple&last_deal_type=3&orderby=cdwl&page_size=100&deal_type=3&dt_select=3&search_type=old&page="
house_links = get_listing_urls(base_url_houses, 25, cookies, headers, existing_links_houses)

# %% [markdown]
# ### Apartments

# %%
existing_links_apartments = pd.read_csv("dataset_apartments.csv").Link.values
base_url_apartments = "https://www.kv.ee/?act=search.simple&last_deal_type=1&orderby=cdwl&page_size=100&deal_type=1&search_type=old&page="
apartment_links = get_listing_urls(base_url_apartments, 52, cookies, headers, existing_links_apartments)
# Out:
# Links so far: 100.
# Links so far: 200.
# Links so far: 300.
# Links so far: 400.
# Links so far: 500.
# Links so far: 600.
# Links so far: 700.
# Links so far: 800.
# Links so far: 900.
# Links so far: 1000.
# Links so far: 1100.
# Links so far: 1200.
# Links so far: 1300.
# Links so far: 1400.
# Links so far: 1500.
# Links so far: 1600.
# Links so far: 1700.
# Links so far: 1800.
# Links so far: 1900.
# Links so far: 2000.
# Links so far: 2100.
# Links so far: 2200.
# Links so far: 2300.
# Links so far: 2369.
# Links so far: 2369.
# Links so far: 100.
# Links so far: 200.
# Links so far: 300.
# Links so far: 400.
# Links so far: 500.
# Links so far: 600.
# Links so far: 700.
# Links so far: 800.
# Links so far: 900.
# Links so far: 1000.
# Links so far: 1100.
# Links so far: 1200.
# Links so far: 1300.
# Links so far: 1400.
# Links so far: 1500.
# Links so far: 1600.
# Links so far: 1700.
# Links so far: 1800.
# Links so far: 1900.
# Links so far: 2000.
# Links so far: 2100.
# Links so far: 2200.
# Links so far: 2300.
# Links so far: 2400.
# Links so far: 2500.
# Links so far: 2600.
# Links so far: 2700.
# Links so far: 2800.
# Links so far: 2900.
# Links so far: 3000.
# Links so far: 3100.
# Links so far: 3200.
# Links so far: 3300.
# Links so far: 3400.
# Links so far: 3500.
# Links so far: 3600.
# Links so far: 3700.
# Links so far: 3800.
# Links so far: 3900.
# Links so far: 4000.
# Links so far: 4100.
# Links so far: 4200.
# Links so far: 4300.
# Links so far: 4400.
# Links so far: 4500.
# Links so far: 4600.
# Links so far: 4700.
# Links so far: 4800.
# Links so far: 4900.
# Links so far: 5000.
# Links so far: 5100.
# Links so far: 5120.

# %% [markdown]
# ### Sharehouses

# %%
# existing_links_sharehouses = pd.read_csv("dataset_sharehouses.csv").Link.values
existing_links_sharehouses = []
base_url_sharehouses = "https://www.kv.ee/?act=search.simple&last_deal_type=11&page_size=100&deal_type=11&dt_select=11&search_type=old&page="
sharehouse_links = get_listing_urls(base_url_sharehouses, 6, cookies, headers, existing_links_sharehouses)
# Out:
# Links so far: 100.
# Links so far: 200.
# Links so far: 300.
# Links so far: 400.
# Links so far: 500.
# Links so far: 509.

# %%
def extract_fields(text):
    results = {}

    try:
        split_text = text.split("<br/>")

        # print(split_text)
        results["Description"] = split_text[0][3:]

        for i in range(2, len(split_text) - 1):
            field = split_text[i].split("</strong> ")
            # print(field)
            results[field[0][8:len(field[0]) - 1]] = field[1].strip()
    finally:
        return results

# %%
def parse_listings(links, cookies, headers, save=True, filename="dataset_.csv", verbose=False):
    data = pd.DataFrame(columns=["Title", "Description", "Link", "Location"]) #, "Rooms", "Bedrooms", "Üldpind", "Korruseid", "Ehitusaasta", "Omandivorm", "Krundi pind", "Energiamärgis"])

    try:
        for i, link in enumerate(links):
            # print(link)   
            response = requests.get(link, headers=headers, cookies=cookies)

            soup = BeautifulSoup(response.text, 'html.parser')

            # Get the short description (title).
            title = soup.title.string.split(" - Kinnisvaraportaal KV.EE ")[0]
            if verbose:
                print(title)

            df = pd.read_html(response.text, attrs={"class":"table-lined object-data-meta"}, flavor="bs4", skiprows=[9, 10], index_col=0)[0]
            # Rename the column to the index of the advertisement.
            df.rename(columns={df.columns.values[0]: i}, inplace=True)
            # Add the short description
            df.loc["Title"] = title
            df.loc["Link"] = link
            
            # Since we cannot be sure these fields always exists, use error handling.
            try:
                # Add the additional fields.
                fields = soup.find("div", attrs={"class":"object-article-body"})
                fields = fields.find("p")
                # fields = fields.findAll("strong")
                # for field in fields:
                #     print(field)

                extracted_fields = extract_fields(str(fields))
                for field in extracted_fields:
                    # print(field)
                    df.loc[field] = extracted_fields[field]

                # Add the location info.
                location = soup.find("a", attrs={"class":"gtm-object-map"})
                df.loc["Location"] = location["href"].split("query=")[1]
            except Exception as e:
                print(e)

            data = data.append(df.T)

            if (i + 1) % 50 == 0:
                print(f"Parsed so far: {i + 1}")
                # break
            
            # break
    # Just print out the exceptions in order not to lose all progress.
    except Exception as e:
        print(e)
    finally:
        if save:
            data.to_csv(filename, index=False)
        return data

# %%
# parsed_houses = parse_listings(house_links, cookies, headers, filename="dataset_houses.csv")
# parsed_apartments = parse_listings(apartment_links, cookies, headers, filename="dataset_apartments.csv")
parsed_sharehouses = parse_listings(sharehouse_links, cookies, headers, filename="dataset_sharehouses.csv")
# Out:
# Parsed so far: 50
# Parsed so far: 100
# Parsed so far: 150
# Parsed so far: 200
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# Parsed so far: 250
# 'NoneType' object is not subscriptable
# Parsed so far: 300
# 'NoneType' object is not subscriptable
# Parsed so far: 350
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# Parsed so far: 400
# 'NoneType' object is not subscriptable
# Parsed so far: 450
# 'NoneType' object is not subscriptable
# Parsed so far: 500

# %%
print(parsed_sharehouses.columns)
display(parsed_sharehouses)
# Out:
# Index(['Title', 'Description', 'Link', 'Location', 'Rooms', 'Bedrooms',
#        'Total area', 'Number of floors', 'Built in year', 'Condition',
#        'Ownership', 'Ground area', 'Notify about incorrect advertisement',
#        'Lisainfo', 'Sanitary arrangements', 'Heating and ventilation',
#        'Communications and security', 'Neighbourhood',
#        'Data from realestate book', 'Kitchen', 'Readiness', 'Register number',
#        'Energy mark', 'Cadastre no.', 'This floor/Number of floors',
#        'Kulud suvel/talvel', 'Additional information'],
#       dtype='object')
#                                                  Title  \
# 0    Row house box for sale, 3 bedrooms, Hansu 3, H...
# 1    Maisonette for sale, 4 bedrooms, Vanatoa tee 1...
# 2    Row house box for sale, 4 bedrooms, Vanatoa te...
# 3    Row house box for sale, 3 bedrooms, Kaare tee ...
# 4    Row house box for sale, 3 bedrooms, Kaare tee ...
# ..                                                 ...
# 504  Maisonette for sale, Riia mnt 55, Kesklinn, Pä...
# 505  Maisonette for sale, 3 bedrooms, Võru tn 46, K...
# 506  Maisonette for sale, Tallinna mnt 21, Võru, Võ...
# 507  Maisonette for sale, 4 bedrooms, Kiipsu tee 5,...
# 508  Maisonette for sale, 3 bedrooms, Koidula tn 19...
#
#                                            Description  \
# 0    Apartment ownership, stone house, total area 1...
# 1    Apartment ownership, wooden house, total area ...
# 2    Apartment ownership, wooden house, total area ...
# 3    Apartment ownership, stone house, total area 1...
# 4    Apartment ownership, stone house, total area 1...
# ..                                                 ...
# 504  Apartment association, wooden house, total are...
# 505  Apartment ownership, stone house, total area 1...
# 506             Apartment ownership, total area 111 m²
# 507  Private ownership, wooden house, house area 15...
# 508                     Stone house, total area 130 m²
#
#                                                   Link  \
# 0    https://www.kv.ee/pakkumisel-viimane-ridaelamu...
# 1    https://www.kv.ee/httpsrabarebase-eekiili-alev...
# 2    https://www.kv.ee/rabarebase-aedlinn-on-tervik...
# 3    https://www.kv.ee/muua-uus-ridamaja-boks-ainul...
# 4    https://www.kv.ee/muua-uus-ridamaja-boks-ainul...
# ..                                                 ...
# 504  https://www.kv.ee/tegemist-on-rikka-ajalooga-m...
# 505  https://www.kv.ee/muua-4toaline-ridaelamuboks-...
# 506  https://www.kv.ee/muua-kaks-korteromandit-kahe...
# 507  https://www.kv.ee/muua-kvaliteetne-energiatohu...
# 508  https://www.kv.ee/kompleks-sunset-beach-club-p...
#
#                             Location Rooms Bedrooms Total area  \
# 0    59.434345102142,24.551863761278     4        3   147.5 m²
# 1                59.292014,24.863741     5        4    90.4 m²
# 2                59.441433,24.899824     5        4   107.6 m²
# 3               59.3909128,24.796628     4        3   123.9 m²
# 4               59.3909128,24.796628     4        3     124 m²
# ..                               ...   ...      ...        ...
# 504            58.3821146,24.5199999    10      NaN   160.9 m²
# 505            58.3709809,26.7223744     4        3   114.4 m²
# 506            57.8597455,26.9709845     6      NaN     111 m²
# 507            59.2799412,24.6694508     5        4   159.5 m²
# 508            59.4423691,28.0119171     4        3     130 m²
#
#     Number of floors Built in year      Condition  ...  \
# 0                  2          2021  all brand-new  ...
# 1                  2          2022  all brand-new  ...
# 2                  2          2022  all brand-new  ...
# 3                  2          2021  all brand-new  ...
# 4                  2          2021  all brand-new  ...
# ..               ...           ...            ...  ...
# 504                1           NaN      renovated  ...
# 505                2          2021  all brand-new  ...
# 506                2          1959   satisfactory  ...
# 507                1          2021  all brand-new  ...
# 508                2          2022  all brand-new  ...
#
#                                          Neighbourhood  \
# 0                     near forest, water body sea near
# 1                                                  NaN
# 2                                                  NaN
# 3    Ülemiste lake , near forest, surrounding build...
# 4    location in the center location, surrounding b...
# ..                                                 ...
# 504                                                NaN
# 505  location in the center location, roads in good...
# 506  location in suburb location, roads in good con...
# 507  surrounding buildings private houses, neighbou...
# 508                   water body water body other near
#
#      Data from realestate book         Kitchen Readiness Register number  \
# 0                          NaN             NaN       NaN             NaN
# 1    Data from realestate book             NaN       NaN             NaN
# 2    Data from realestate book  electric stove       NaN             NaN
# 3    Data from realestate book             NaN     ready        11913202
# 4    Data from realestate book             NaN     ready        11913202
# ..                         ...             ...       ...             ...
# 504  Data from realestate book             NaN       NaN             NaN
# 505  Data from realestate book             NaN     ready             NaN
# 506                        NaN             NaN     ready             NaN
# 507  Data from realestate book             NaN     ready             NaN
# 508  Data from realestate book             NaN       NaN             NaN
#
#     Energy mark Cadastre no. This floor/Number of floors Kulud suvel/talvel  \
# 0           NaN          NaN                         NaN                NaN
# 1           NaN          NaN                         NaN                NaN
# 2           NaN          NaN                         NaN                NaN
# 3             A          NaN                         NaN                NaN
# 4             A          NaN                         NaN                NaN
# ..          ...          ...                         ...                ...
# 504     Missing          NaN                         NaN                NaN
# 505           A          NaN                         NaN                NaN
# 506         NaN          NaN                         NaN                NaN
# 507           A          NaN                         NaN                NaN
# 508     Missing          NaN                         NaN                NaN
#
#     Additional information
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ..                     ...
# 504                    NaN
# 505                    NaN
# 506                    NaN
# 507                    NaN
# 508                    NaN
#
# [509 rows x 27 columns]

# %%
test_data = pd.read_csv("dataset_houses.csv")
test_data
# Out:
#                                                   Title  \
# 0     House for sale, 6 bedrooms, Käokeele tee 13, A...
# 1     House for sale, 3 bedrooms, Pirnipuu pst 174, ...
# 2     House for sale, 7 bedrooms, Sassi tn 4, Karlov...
# 3     House for sale, 3 bedrooms, Sassi tn 4a, Karlo...
# 4     House for sale, 3 bedrooms, Karukella tee 2, P...
# ...                                                 ...
# 2364  House for sale, Viljandi mnt 54, Rapla linn, R...
# 2365  House for sale, Veski tn 13, Valga linn, Valga...
# 2366  House for sale,  Mureli, Suure-Ahli, Haapsalu,...
# 2367  Farmhouse for sale, Kundihüti, Luhametsa, Ants...
# 2368  Cottage for sale, Lalli, Kambja vald, Tartumaa...
#
#                                             Description  \
# 0     Private ownership, stone house, total area 209...
# 1     Private ownership, stone house, total area 171...
# 2                Private ownership, total area 257.2 m²
# 3     Private ownership, stone house, total area 121...
# 4     Private ownership, stone house, total area 158...
# ...                                                 ...
# 2364  Private ownership, panel house, total area 181...
# 2365   Joint ownership, wooden house, total area 175 m²
# 2366  Private ownership, panel house, total area 145...
# 2367     Private ownership, log house, total area 73 m²
# 2368  Private ownership, wooden house, house area 70 m²
#
#                                                    Link  \
# 0     https://www.kv.ee/muuki-tuli-suur-stiilne-ja-a...
# 1     https://www.kv.ee/muua-2022-aasta-alguses-valm...
# 2     https://www.kv.ee/soodushind-450-000-tavahind-...
# 3     https://www.kv.ee/muua-hoovimaja-mis-jagatud-k...
# 4     https://www.kv.ee/valgeranna-sissesoidutee-aar...
# ...                                                 ...
# 2364  https://www.kv.ee/muua-1979-aastal-valminud-ka...
# 2365  https://www.kv.ee/valga-linnas-muua-2-kordne-e...
# 2366  https://www.kv.ee/kaunilt-haljastatud-krundil-...
# 2367  https://www.kv.ee/vana-talukoht-vorumaa-kuplit...
# 2368  https://www.kv.ee/maenolval-ilusa-vaatega-pori...
#
#                             Location  Rooms  Bedrooms Total area  \
# 0              59.3677577,24.5949667    7.0       6.0   209.1 m²
# 1              59.4689483,24.9601375    4.0       3.0   171.2 m²
# 2              58.3754678,26.7311085   12.0       7.0   257.2 m²
# 3              58.3754678,26.7311085    6.0       3.0   121.1 m²
# 4              58.3674254,24.5676331    4.0       3.0   158.9 m²
# ...                              ...    ...       ...        ...
# 2364             58.999085,24.805968    4.0       NaN   181.7 m²
# 2365             57.769506,26.053295    4.0       NaN     175 m²
# 2366             58.867395,23.527873    4.0       NaN   145.8 m²
# 2367  57.767080520473,26.71936923858    NaN       NaN      73 m²
# 2368           58.2351777,26.6933794    2.0       NaN        NaN
#
#       Number of floors  Built in year         Condition  ...  \
# 0                  2.0         2020.0     all brand-new  ...
# 1                  NaN         2022.0     all brand-new  ...
# 2                  2.0         2017.0    Good condition  ...
# 3                  2.0         2019.0    Good condition  ...
# 4                  2.0         2022.0     all brand-new  ...
# ...                ...            ...               ...  ...
# 2364               2.0         1979.0             ready  ...
# 2365               2.0         1978.0             ready  ...
# 2366               3.0            NaN             ready  ...
# 2367               2.0            NaN  needs renovating  ...
# 2368               2.0         1990.0     all brand-new  ...
#
#                                   Sanitary arrangements  \
# 0                             bath, shower, urban water
# 1     sauna, toilet room and bathroom separate, wate...
# 2     toilet room and bathroom separate, sauna, bath...
# 3                                                   NaN
# 4     shower, toilet room and bathroom separate, sau...
# ...                                                 ...
# 2364  water boiler, toilet room and bathroom separat...
# 2365                      shower, sewerage, urban water
# 2366                                             shower
# 2367                                                NaN
# 2368                                                NaN
#
#                                 Heating and ventilation  \
# 0                                    geothermic heating
# 1     õhksoojuspump, heated floors, fireplace, condi...
# 2                          õhksoojuspump, heated floors
# 3                                                   NaN
# 4                     heated floors, geothermic heating
# ...                                                 ...
# 2364                                      stove heating
# 2365                                      stove heating
# 2366                                         solid fuel
# 2367                                                NaN
# 2368                           stove heating, fireplace
#
#                             Communications and security  \
# 0     Internet, phone, cable TV, neighbourhood watch...
# 1                                  Internet, steel door
# 2                   Internet, phone, fenced with garden
# 3                                                   NaN
# 4     Internet, cable TV, security system, fenced wi...
# ...                                                 ...
# 2364                                                NaN
# 2365                                                NaN
# 2366                                                NaN
# 2367                                                NaN
# 2368                                neighbourhood watch
#
#      This floor/Number of floors  \
# 0                            NaN
# 1                            1/1
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 2364                         NaN
# 2365                         NaN
# 2366                         NaN
# 2367                         NaN
# 2368                         NaN
#
#                                           Neighbourhood Ground area  \
# 0                                                   NaN         NaN
# 1     surrounding buildings private houses and apart...         NaN
# 2     roads in good condition roads, surrounding bui...      703 m²
# 3                                                   NaN         NaN
# 4     Audru river 400 m, surrounding buildings priva...     1336 m²
# ...                                                 ...         ...
# 2364                                                NaN     1369 m²
# 2365                                                NaN     1053 m²
# 2366                                                NaN     3170 m²
# 2367                      roads in good condition roads    12419 m²
# 2368                              water body river near     2234 m²
#
#      Kulud suvel/talvel    Cadastre no. Register number  \
# 0                   NaN             NaN             NaN
# 1                   NaN             NaN             NaN
# 2                   NaN             NaN             NaN
# 3         50 € /  100 €             NaN             NaN
# 4                   NaN             NaN             NaN
# ...                 ...             ...             ...
# 2364                NaN  67001:008:0190             NaN
# 2365                NaN  85401:008:0480             NaN
# 2366                NaN  67401:006:0204       1538032.0
# 2367                NaN  14303:003:0063       2235341.0
# 2368                NaN             NaN             NaN
#
#          Additional information
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 2364                        NaN
# 2365  water, roof profiled roof
# 2366                        NaN
# 2367                        NaN
# 2368       electricity, terrace
#
# [2369 rows x 27 columns]
